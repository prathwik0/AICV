# %% [markdown]
# # Write a program in python to perform different morphological operations on images using OpenCV

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("../imagedata/imgabcd.jpg")
plt.imshow(img)

# %% [markdown]
# ## Erosion

# %%
img = cv2.imread("../imagedata/imgabcd.jpg", 0)
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
kernel = np.ones((5, 5), np.uint8)
invert = cv2.bitwise_not(binr)
erosion = cv2.erode(invert, kernel, iterations=1)
plt.imshow(erosion, cmap="gray")

# %% [markdown]
# ## Dilation

# %%
img = cv2.imread("../imagedata/imgabcd.jpg", 0)
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
kernel = np.ones((3, 3), np.uint8)
invert = cv2.bitwise_not(binr)
dilation = cv2.dilate(invert, kernel, iterations=1)
plt.imshow(dilation, cmap="gray")

# %% [markdown]
# ## Opening

# %%
img = cv2.imread("../imagedata/imgabcd.jpg", 0)
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
kernel = np.ones((3, 3), np.uint8)
opening = cv2.morphologyEx(binr, cv2.MORPH_OPEN, kernel, iterations=1)
plt.imshow(opening, cmap="gray")

# %% [markdown]
# ## Closing

# %%
img = cv2.imread("../imagedata/imgabcd.jpg", 0)
binr = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
kernel = np.ones((3, 3), np.uint8)
opening = cv2.morphologyEx(binr, cv2.MORPH_CLOSE, kernel, iterations=1)
plt.imshow(opening, cmap="gray")
